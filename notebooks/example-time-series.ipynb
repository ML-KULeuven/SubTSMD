# %%
from sub_tsmd import plot_motif_sets, load, load_validation
import seaborn as sns
sns.set_theme()

# %%
X, y = load('../data/synthetic/demonstration/subspace.pkl')
plot_motif_sets(X, y, figsize=(20, 12));

# %%
Xs, ys = load_validation('../data/sub-tsmd-bench/articularywordrecognition')
plot_motif_sets(Xs[0], ys[0], figsize=(20, 12))

# %%
Xs, ys = load_validation('../data/noisy-attributes/s1@synthetic#16-noisy')
plot_motif_sets(Xs[0], ys[0], figsize=(20, 12));

# %%
Xs, ys = load_validation('../data/noisy-data/s1@synthetic#0.5-snr')
plot_motif_sets(Xs[0], ys[0], figsize=(20, 12));

# %%
Xs, ys = load_validation('../data/physical-therapy/e1')
plot_motif_sets(Xs[0], ys[0], figsize=(20, 12));
